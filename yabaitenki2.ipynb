# %%
import keras
import keras
from keras.utils import np_utils
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.preprocessing.image import array_to_img, img_to_array, list_pictures, load_img
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("data_all.csv")
# df.head()

x, t = [], []

for (i, row) in df.iterrows():
    filepath = row['filepath']
    tmp_img = load_img(filepath, target_size=(32,32))
    img = img_to_array(tmp_img) / 255.0 # -> float32 + 正規化
    
    # データに追加
    x.append(img)
    t.append(row['label'])
    
# numpyに変換
x = np.array(x, 'f')

# x.shape

# クラスの形式を変換 <- one-hot表現
t = np_utils.to_categorical(t, 2)

# 学習用データとテストデータ
x_train, x_test, t_train, t_test = train_test_split(x, t, test_size=0.33, random_state=1)
# Out:
# Using TensorFlow backend.

# %%
# CNNを構築
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))       # クラスは2個
model.add(Activation('softmax'))

# コンパイル
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# 実行。出力はなしで設定(verbose=0)。
history = model.fit(x_train, t_train, batch_size=30, epochs=50,
                   validation_data = (x_test, t_test))

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['acc', 'val_acc'], loc='lower right')
plt.show()
# Out:
# Train on 824 samples, validate on 406 samples
# Epoch 1/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.7543 - acc: 0.5740 - val_loss: 0.6495 - val_acc: 0.6305
# Epoch 2/50
# 824/824 [==============================] - 9s 11ms/step - loss: 0.6442 - acc: 0.6420 - val_loss: 0.6443 - val_acc: 0.6133
# Epoch 3/50
# 824/824 [==============================] - 10s 12ms/step - loss: 0.6051 - acc: 0.6578 - val_loss: 0.6354 - val_acc: 0.6527
# Epoch 4/50
# 824/824 [==============================] - 10s 12ms/step - loss: 0.5825 - acc: 0.6833 - val_loss: 0.6371 - val_acc: 0.6453
# Epoch 5/50
# 824/824 [==============================] - 8s 10ms/step - loss: 0.5625 - acc: 0.7197 - val_loss: 0.6510 - val_acc: 0.6675
# Epoch 6/50
# 824/824 [==============================] - 8s 9ms/step - loss: 0.4955 - acc: 0.7476 - val_loss: 0.6258 - val_acc: 0.6404
# Epoch 7/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.4654 - acc: 0.7621 - val_loss: 0.7061 - val_acc: 0.6453
# Epoch 8/50
# 824/824 [==============================] - 8s 9ms/step - loss: 0.3994 - acc: 0.8083 - val_loss: 0.6932 - val_acc: 0.6453
# Epoch 9/50
# 824/824 [==============================] - 7s 9ms/step - loss: 0.3466 - acc: 0.8568 - val_loss: 0.7445 - val_acc: 0.6502
# Epoch 10/50
# 824/824 [==============================] - 7s 9ms/step - loss: 0.3055 - acc: 0.8604 - val_loss: 0.9325 - val_acc: 0.6355
# Epoch 11/50
# 824/824 [==============================] - 6s 7ms/step - loss: 0.2556 - acc: 0.8932 - val_loss: 0.9188 - val_acc: 0.6429
# Epoch 12/50
# 824/824 [==============================] - 6s 7ms/step - loss: 0.2189 - acc: 0.9223 - val_loss: 1.0003 - val_acc: 0.6281
# Epoch 13/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.2293 - acc: 0.9005 - val_loss: 1.1855 - val_acc: 0.6034
# Epoch 14/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.1563 - acc: 0.9417 - val_loss: 1.2893 - val_acc: 0.6108
# Epoch 15/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.1948 - acc: 0.9248 - val_loss: 1.2438 - val_acc: 0.6232
# Epoch 16/50
# 824/824 [==============================] - 6s 7ms/step - loss: 0.1227 - acc: 0.9600 - val_loss: 1.2975 - val_acc: 0.6108
# Epoch 17/50
# 824/824 [==============================] - 6s 7ms/step - loss: 0.1124 - acc: 0.9684 - val_loss: 1.4076 - val_acc: 0.6232
# Epoch 18/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.0679 - acc: 0.9818 - val_loss: 1.6118 - val_acc: 0.6182
# Epoch 19/50
# 824/824 [==============================] - 6s 7ms/step - loss: 0.0870 - acc: 0.9733 - val_loss: 1.5085 - val_acc: 0.6207
# Epoch 20/50
# 824/824 [==============================] - 6s 8ms/step - loss: 0.